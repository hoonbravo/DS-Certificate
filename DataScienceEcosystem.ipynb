# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem
# ![2-title.png](attachment:89277632-4f86-4806-b058-449e7eb44435.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
# ![3-intro.png](attachment:0fb694bf-23ce-4f80-a00c-ffe0a77e9619.png)

# %% [markdown]
# **Objectives:** unordered list
# List popular languages for Data Science:
# * Python
# * R
# * SQL
# ![10-objectives.png](attachment:b0e5f940-4dab-485d-9e62-5a04809545cf.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# ![4-sdlanguages.png](attachment:9ee5867d-695b-4113-b150-559049444bed.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# ![5-dslibraries.png](attachment:e4f0f4d8-b36c-44b2-8dd8-20f482574dd9.png)

# %% [markdown]
# ## Data Science Tools
#
# | Data Science Tools        |
# |---------------------------|
# | Jupyter Notebook          |
# | RStudio                   |
# | Spyder                    |
#
# ![6-dstools.png](attachment:25237acc-dc8f-4cac-8a22-4098348de007.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
# ![7-introarithmetic.png](attachment:3c3345f1-fd99-472a-9dcc-ce8bb2e4c90c.png)

# %%
a = (3*4)+5
## This a simple arithmetic expression to mutiply then add integers
print(a)
# Out:
# 17

# %% [markdown]
# ![8-multplyandaddintegers.png](attachment:336add96-c304-4e62-8680-d1894de64538.png)

# %%
## This will convert 200 minutes to hours by diving by 60
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:bd8d1247-3245-4f44-bfb6-cee30bfc681c.png)

# %% [markdown]
# ## Author
# Simon
# ![11-authordetails.png](attachment:4045356c-60fc-40a7-b7cd-e2b24a3cb501.png)
